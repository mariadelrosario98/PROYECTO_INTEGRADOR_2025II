# %%
# !pip install pyarrow
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from pandas.api.types import (
    is_string_dtype, is_float_dtype, is_integer_dtype,
    is_object_dtype, is_bool_dtype, is_categorical_dtype
)

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\final_labeled.csv", sep=',', encoding='latin-1')

# %%
geih_diccionario = {
    "PERIODO": "Periodo de referencia",
    "MES": "Mes de referencia",
    "PER": "Código del periodo",
    "DIRECTORIO": "Número de directorio del hogar",
    "SECUENCIA_P": "Número de la vivienda dentro del directorio",
    "ORDEN": "Número de orden de la persona",
    "HOGAR": "Número de hogar",
    "REGIS": "Registro de la encuesta",
    "AREA": "Área (urbana/rural)",
    "CLASE": "Clase de lugar",
    "FEX_C18": "Factor de expansión",
    "DPTO": "Departamento",
    "PT": "Punto de encuesta",
    "P6016": "Número de orden de quien proporciona la información",
    "P3271": "Sexo al nacer",
    "P6040": "Edad en años cumplidos",
    "P6030S1": "Mes de nacimiento",
    "P6030S3": "Año de nacimiento",
    "P6050": "Parentesco con el jefe(a) del hogar",
    "P6083": "¿Madre reside en el hogar?",
    "P6083S1": "Número de orden de la madre",
    "P6081": "¿Padre reside en el hogar?",
    "P6081S1": "Número de orden del padre",
    "P2057": "¿Se considera campesino(a)?",
    "P2059": "¿Alguna vez fue campesino(a)?",
    "P2061": "¿Su comunidad es campesina?",
    "P6080": "Autoidentificación étnica",
    "P6080S1": "Pueblo o etnia indígena",
    "P6080S1A1": "Nombre específico del pueblo",
    "P6071": "¿Cónyuge reside en el hogar?",
    "P6071S1": "Número de orden del cónyuge",
    "P3147S1": "COVID: estuvo enfermo(a)",
    "P3147S2": "COVID: dificultad con alimentos/productos",
    "P3147S3": "COVID: dificultad con pagos/deudas",
    "P3147S4": "COVID: reducción de ingresos",
    "P3147S5": "COVID: sin trabajo o sin poder buscarlo",
    "P3147S6": "COVID: suspensión contrato sin paga",
    "P3147S7": "COVID: pérdida de trabajo o ingresos",
    "P3147S8": "COVID: suspensión de clases",
    "P3147S9": "COVID: malestar emocional",
    "P3147S10": "COVID: otra dificultad",
    "P3147S11": "COVID: sin dificultades",
    "P3147S10A1": "COVID: otra dificultad - detalle",
    "P6090": "Afiliación sistema de salud",
    "P6100": "Régimen de salud",
    "P6110": "Quién paga la afiliación",
    "P6120": "Monto pagado afiliación",
    "P1906S1": "Dificultad auditiva",
    "P1906S2": "Dificultad para hablar",
    "P1906S3": "Dificultad visual",
    "P1906S4": "Dificultad motriz",
    "P1906S5": "Dificultad en manos",
    "P1906S6": "Dificultad cognitiva",
    "P1906S7": "Dificultad en autocuidado",
    "P1906S8": "Dificultad para relacionarse",
    "P6160": "¿Sabe leer y escribir?",
    "P6170": "¿Asiste actualmente a clase?",
    "P3041": "Tipo de institución educativa",
    "P3042": "Nivel educativo y grado aprobado",
    "P3042S1": "Grado o año alcanzado",
    "P3042S2": "Área de estudio",
    "P3043": "Título o diploma recibido",
    "P3043S1": "Área del título",
    "P3038": "Orientación sexual o romántica",
    "P3039": "Identidad de género",
    "POB_MAY18": "Es mayor de 18 años",
    "LGB_Numerica": "Identificación LGB (número)",
    "LGB_sectores": "LGB - sectores",
    "LGBT_Numerica": "Identificación LGBT (número)",
    "Trans_numerica": "Identificación Trans (número)",
    "Discapacidad": "Condición de discapacidad",
    "Dificultad": "Tipo de dificultad funcional",
    "Campesina": "Pertenencia a comunidad campesina"
}

# %%
df = df.rename(columns=geih_diccionario)

# %%
diccionario_mti = {
    "DIRECTORIO": "Identificador del hogar",
    "SECUENCIA_P": "Identificador de la vivienda dentro del hogar",
    "TAM_HOGAR": "Tamaño del hogar",
    "ORDEN": "Número secuencial del miembro del hogar",
    "P3271": "Sexo al nacer",
    "P6040": "Edad en años cumplidos",
    "P6050": "Parentesco con el jefe del hogar",
    "P6070": "Estado civil",
    "P6090": "Afiliación a EPS o régimen de salud",
    "P6100": "Régimen de salud al que está afiliado",
    "P6110": "Régimen subsidiado o contributivo",
    "P6120": "Afiliación a otro tipo de régimen",
    "P6160": "¿Sabe leer y escribir?",
    "P6170": "¿Asiste a una institución educativa?",
    "P3041": "Tipo de institución educativa",
    "P3042": "Nivel y grado educativo aprobado",
    "P3042S1": "Año o grado alcanzado (1)",
    "P3042S2": "Año o grado alcanzado (2)",
    "CLASE": "Zona: cabecera o resto",
    "P400": "Actividad principal la semana pasada",
    "P401": "Actividad adicional remunerada la semana pasada",
    "P402": "Tenía trabajo aunque no haya trabajado esa semana",
    "P403": "Trabajo sin remuneración la semana pasada",
    "P404": "Búsqueda de trabajo en las últimas 4 semanas",
    "P3564": "¿Recibió remuneración por el trabajo?",
    "P405": "Razón principal para trabajar",
    "P408": "Condición de ocupación",
    "P409": "Ingreso mensual bruto en el empleo principal",
    "P410": "¿Recibió alimentos como pago?",
    "P410S1": "Valor estimado de alimentos recibidos",
    "P411": "¿Recibió vivienda como pago?",
    "P411S1": "Valor estimado de la vivienda recibida",
    "P412": "¿Recibió otros ingresos en especie?",
    "P412S1": "Valor estimado de otros ingresos en especie",
    "P413": "Ganancia neta en actividad económica",
    "P414": "Meses trabajados en los últimos 12 meses",
    "P415": "Horas semanales normalmente trabajadas",
    "P416": "Horas trabajadas la semana pasada",
    "P420": "Lugar principal donde realiza el trabajo",
    "P423": "Razón por la que colabora en los oficios",
    "RAMA4D_R4": "Actividad económica de la empresa (CIIU 4 dígitos)",
    "RAMA2D_R4": "Actividad económica de la empresa (CIIU 2 dígitos)",
    "FEX_C": "Factor de expansión del hogar",
    "AREA": "Área geográfica",
    "OFICIO_C8": "Código de oficio a 8 dígitos",
}

# %%
df = df.rename(columns=diccionario_mti)

# %%
diccionario_vivienda = {
    "PERIODO": "Periodo de la encuesta",
    "MES": "Mes de referencia",
    "PER": "Número de persona",
    "DIRECTORIO": "Identificador del hogar",
    "SECUENCIA_P": "Identificador de la vivienda dentro del hogar",
    "HOGAR": "Número de hogar en la vivienda",
    "REGIS": "Registro de la encuesta",
    "AREA": "Zona (urbana/rural)",
    "CLASE": "Clase (cabecera o resto)",
    "FEX_C18": "Factor de expansión corregido",
    "DPTO": "Departamento",
    "P4000": "Tipo de vivienda",
    "P4010": "Material predominante de las paredes exteriores",
    "P4020": "Material predominante del piso",
    "P4030S1": "Disponibilidad de energía eléctrica",
    "P4030S1A1": "Estrato para tarifa de electricidad",
    "P4030S2": "Disponibilidad de gas natural por red pública",
    "P4030S3": "Disponibilidad de alcantarillado",
    "P4030S4": "Disponibilidad de recolección de basuras",
    "P4030S4A1": "Frecuencia de recolección de basura (veces por semana)",
    "P4030S5": "Disponibilidad de acueducto",
    "P70": "Cantidad de hogares en la vivienda",
    "P5000": "Número total de cuartos disponibles en el hogar",
    "P5010": "Número de cuartos usados para dormir",
    "P5020": "Tipo de servicio sanitario que utiliza el hogar",
    "P5030": "Forma de disposición del servicio sanitario",
    "P5040": "Método de eliminación de basuras en el hogar",
    "P5050": "Fuente principal de agua para consumo humano",
    "P5070": "Lugar donde se preparan los alimentos",
    "P5080": "Tipo de energía o combustible usado para cocinar",
    "P5090": "Tipo de ocupación de la vivienda",
    "P5090S1": "Especificación del tipo de ocupación",
    "P5100": "Valor mensual pagado por amortización (si aplica)",
    "P5110": "Valor mínimo estimado para venta de la vivienda",
    "P5130": "Valor estimado de arriendo si se tuviera que pagar",
    "P5140": "Valor mensual pagado por arriendo",
    "P5222S1": "Uso de productos financieros (1)",
    "P5222S2": "Uso de productos financieros (2)",
    "P5222S3": "Uso de productos financieros (3)",
    "P5222S4": "Uso de productos financieros (4)",
    "P5222S5": "Uso de productos financieros (5)",
    "P5222S6": "Uso de productos financieros (6)",
    "P5222S7": "Uso de productos financieros (7)",
    "P5222S8": "Uso de productos financieros (8)",
    "P5222S9": "Uso de productos financieros (9)",
    "P5222S10": "Uso de productos financieros (10)",
    "P5222S8A1": "Detalles adicionales sobre productos financieros",
    "p5222": "Otra especificación de productos financieros",
    "p52221": "Otra especificación de productos financieros (variante 1)",
    "p52222": "Otra especificación de productos financieros (variante 2)",
    "P6008": "Total de personas en el hogar",
}

# %%
df = df.rename(columns=diccionario_vivienda)

# %%
df
# Out:
#         key_ninos  primary_key  Periodo de referencia  Mes de referencia  \
# 0       730906013     73090601               20230104                  1
# 1       730906414     73090641               20230104                  1
# 2       730906812     73090681               20230104                  1
# 3       730906913     73090691               20230104                  1
# 4       730907013     73090701               20230104                  1
# ...           ...          ...                    ...                ...
# 176343  756731615     75673161               20230939                  9
# 176344  756731814     75673181               20230939                  9
# 176345  756731815     75673181               20230939                  9
# 176346  756731913     75673191               20230939                  9
# 176347  756732313     75673231               20230937                  9
#
#         Código del periodo  Número de directorio del hogar  \
# ...

# %%
divipola_departamentos = {
    5:  "Antioquia",
    8:  "Atlántico",
    11: "Bogotá, D.C.",
    13: "Bolívar",
    15: "Boyacá",
    17: "Caldas",
    18: "Caquetá",
    19: "Cauca",
    20: "Cesar",
    23: "Córdoba",
    25: "Cundinamarca",
    27: "Chocó",
    41: "Huila",
    44: "La Guajira",
    47: "Magdalena",
    50: "Meta",
    52: "Nariño",
    54: "Norte de Santander",
    63: "Quindío",
    66: "Risaralda",
    68: "Santander",
    70: "Sucre",
    73: "Tolima",
    76: "Valle del Cauca",
    81: "Arauca",
    85: "Casanare",
    86: "Putumayo",
    88: "Archipiélago de San Andrés, Providencia y Santa Catalina",
    91: "Amazonas",
    94: "Guainía",
    95: "Guaviare",
    97: "Vaupés",
    99: "Vichada"
}

# %%
df.to_csv(r"C:\Users\ASUS\Downloads\final2.csv", index=False, encoding='latin-1')

# %%
df['Departamento'] = df['Departamento'].replace(divipola_departamentos)

# %%
P6050_dict = {
    1: "Jefe(a) del hogar",
    2: "Pareja, esposo(a), cónyuge, compañero(a)",
    3: "Hijo(a), hijastro(a)",
    4: "Nieto(a)",
    5: "Otro pariente",
    6: "Empleado(a) del servicio doméstico y sus parientes",
    7: "Pensionista",
    8: "Trabajador",
    9: "Otro no pariente"
}
df['Parentesco con el jefe(a) del hogar'] = df['Parentesco con el jefe(a) del hogar'].replace(P6050_dict)

# %%
cols_disponibilidad = [
    "Disponibilidad de gas natural por red pública",
    "Disponibilidad de alcantarillado",
    "Disponibilidad de recolección de basuras", "Disponibilidad de acueducto"
]

for col in cols_disponibilidad:
    df[col] = df[col].replace(dic_dict)

# %%
dic_dict = {
    1: "Sí",
    2: "No"
}
df['¿Madre reside en el hogar?'] = df['¿Madre reside en el hogar?'].replace(dic_dict)
df['¿Padre reside en el hogar?'] = df['¿Padre reside en el hogar?'].replace(dic_dict)
df['¿Se considera campesino(a)?'] = df['¿Se considera campesino(a)?'].replace(dic_dict)
df['¿Alguna vez fue campesino(a)?'] = df['¿Alguna vez fue campesino(a)?'].replace(dic_dict)
df['¿Su comunidad es campesina?'] = df['¿Su comunidad es campesina?'].replace(dic_dict)
df['¿Cónyuge reside en el hogar?'] = df['¿Cónyuge reside en el hogar?'].replace(dic_dict)
df['COVID: estuvo enfermo(a)'] = df['COVID: estuvo enfermo(a)'].replace(dic_dict)
df['COVID: estuvo enfermo(a)'] = df['COVID: estuvo enfermo(a)'].replace(dic_dict)


cols_covid = [
    'COVID: dificultad con alimentos/productos',
    'COVID: dificultad con pagos/deudas',
    'COVID: reducción de ingresos',
    'COVID: sin trabajo o sin poder buscarlo',
    'COVID: suspensión contrato sin paga',
    'COVID: pérdida de trabajo o ingresos',
    'COVID: suspensión de clases',
    'COVID: malestar emocional',
    'COVID: otra dificultad',
    'COVID: sin dificultades',
    'COVID: otra dificultad - detalle',
    'Afiliación sistema de salud',
]

# Reemplazo en todas las columnas usando el mismo diccionario
for col in cols_covid:
    df[col] = df[col].replace(dic_dict)

# %%
etnia_dict = {
    1: "Indígena",
    2: "Gitano(a) (Rom)",
    3: "Raizal del archipiélago de San Andrés, Providencia y Santa Catalina",
    4: "Palenquero(a) de San Basilio",
    5: "Negro(a), mulato(a) (afrodescendiente), afrocolombiano(a)",
    6: "Ninguno de los anteriores"
}
df['Autoidentificación étnica'] = df['Autoidentificación étnica'].replace(etnia_dict)

# %%
df = df.drop(columns=[
    'Pueblo o etnia indígena',
    'Nombre específico del pueblo',
    'Número de orden del cónyuge',
    'Número de orden de la madre',
    'Número de orden del padre',
    'Monto pagado afiliación'
])

# %%
estado_civil_dict = {
    6: "Está soltero(a)",
    5: "Está viudo(a)",
    4: "Está separado(a) o divorciado(a)",
    3: "Está casado(a)",
    2: "No está casado(a) y vive en pareja hace dos años o más",
    1: "No está casado(a) y vive en pareja hace menos de dos años"
}
df['Estado civil'] = df['Estado civil'].replace(estado_civil_dict)

# %%
afiliacion_salud_dict = {
    9: "No sabe, no informa",
    3: "Subsidiado (EPS-S)",
    2: "Especial (fuerzas armadas, Ecopetrol, universidades públicas)",
    1: "Contributivo (EPS)"
}
df['Régimen de salud'] = df['Régimen de salud'].replace(estado_civil_dict)

# %%
forma_afiliacion_dict = {
    6: "No sabe, no informa",
    5: "No paga, es beneficiario",
    4: "Paga completamente la empresa o patrón donde trabaja o trabajó",
    3: "La persona paga la totalidad de la afiliación",
    2: "Le descuentan de la pensión",
    1: "La persona paga una parte y otra la empresa o patrón"
}
df['Quién paga la afiliación'] = df['Quién paga la afiliación'].replace(estado_civil_dict)

# %%
sector_educativo_dict = {
    1: "Pública",
    2: "Privada"
}
df['Tipo de institución educativa'] = df['Tipo de institución educativa'].replace(sector_educativo_dict)

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['key_ninos', 'primary_key', 'Periodo de referencia', 'Mes de referencia', 'Código del periodo', 'Número de directorio del hogar', 'Número de la vivienda dentro del directorio', 'Número de orden de la persona', 'Número de hogar', 'Registro de la encuesta', 'Área (urbana/rural)', 'Clase de lugar', 'Factor de expansión', 'Departamento', 'Punto de encuesta', 'Número de orden de quien proporciona la información', 'Sexo al nacer', 'Edad en años cumplidos', 'Mes de nacimiento', 'Año de nacimiento', 'Parentesco con el jefe(a) del hogar', '¿Madre reside en el hogar?', '¿Padre reside en el hogar?', '¿Se considera campesino(a)?', '¿Alguna vez fue campesino(a)?', '¿Su comunidad es campesina?', 'Autoidentificación étnica', 'Estado civil', '¿Cónyuge reside en el hogar?', 'COVID: estuvo enfermo(a)', 'COVID: dificultad con alimentos/productos', 'COVID: dificultad con pagos/deudas', 'COVID: reducción de ingresos', 'COVID: sin trabajo o sin poder buscarlo', 'COVID: suspensión contrato sin paga', 'COV
# ...

# %%
cols_a_eliminar = [
    "Orientación sexual o romántica",
    "Identidad de género",
    "Es mayor de 18 años",
    "Identificación LGB (número)",
    "LGB - sectores",
    "Identificación LGBT (número)",
    "Identificación Trans (número)",
    "folder_id",
    "Área de estudio",
    "Título o diploma recibido",
    "Mes de referencia",
    "Número de la vivienda dentro del directorio",
    "Número de orden de la persona",
    "Número de hogar",
    "Registro de la encuesta",
    "Área (urbana/rural)",
    "Clase de lugar",
    "Factor de expansión",
    "Punto de encuesta",
    "Número de orden de quien proporciona la información",
    "Área del título",
    "Tipo de dificultad funcional"
]


cols_existentes = [col for col in cols_a_eliminar if col in df.columns]
df = df.drop(columns=cols_existentes)

# %%
dic_dict_2 = {
    1: "Sí",
    0: "No"
}
df['Condición de discapacidad'] = df['Condición de discapacidad'].replace(dic_dict_2)
df['Pertenencia a comunidad campesina'] = df['Pertenencia a comunidad campesina'].replace(dic_dict_2)
df['Disponibilidad de energía eléctrica'] = df['Disponibilidad de energía eléctrica'].replace(dic_dict)
df['Disponibilidad de gas natural por red pública'] = df['Disponibilidad de gas natural por red pública'].replace(dic_dict)

# %%
tipo_vivienda_dict = {
    6: "Otra vivienda (carpa, vagón, embarcación, cueva, refugio natural, etc.)",
    5: "Vivienda indígena",
    4: "Cuarto(s) en otro tipo de estructura",
    3: "Cuarto(s) en inquilinato",
    2: "Apartamento",
    1: "Casa"
}
df['Tipo de vivienda'] = df['Tipo de vivienda'].replace(tipo_vivienda_dict)

# %%
material_paredes_dict = {
    9: "Sin paredes",
    8: "Zinc, tela, cartón, latas, desechos, plástico",
    7: "Caña, esterilla, otro tipo de material vegetal",
    6: "Guadua",
    5: "Madera burda, tabla, tablón",
    4: "Bahareque",
    3: "Adobe o tapia pisada",
    2: "Madera pulida",
    1: "Ladrillo, bloque, material prefabricado, piedra"
}
df['Material predominante de las paredes exteriores'] = df['Material predominante de las paredes exteriores'].replace(material_paredes_dict)
material_piso_dict = {
    9: "Tierra, arena, barro",
    8: "Cemento sin pulir",
    7: "Cemento pulido",
    6: "Madera burda, tabla, tablón",
    5: "Madera pulida",
    4: "Cerámica, mosaico, mármol",
    3: "Vinilo o linóleo",
    2: "Alfombra o tapete",
    1: "Otro tipo de material"
}

df['Material predominante del piso'] = df['Material predominante del piso'].replace(material_paredes_dict)

# %%
estrato_dict = {
    9: "No sabe o cuenta con planta eléctrica",
    6: "Alto",
    5: "Medio - alto",
    4: "Medio",
    3: "Medio - bajo",
    2: "Bajo",
    1: "Bajo - bajo",
    0: "Conexión pirata"
}
df['Estrato para tarifa de electricidad'] = df['Estrato para tarifa de electricidad'].replace(material_paredes_dict)

# %%
servicio_sanitario_dict = {
    6: "No tiene servicio sanitario",
    5: "Bajamar",
    4: "Letrina",
    3: "Inodoro sin conexión",
    2: "Inodoro conectado a pozo séptico",
    1: "Inodoro conectado a alcantarillado"
}
df["Tipo de servicio sanitario que utiliza el hogar"] = df["Tipo de servicio sanitario que utiliza el hogar"].replace(servicio_sanitario_dict)

# %%
uso_servicio_sanitario_dict = {
    2: "Compartido con personas de otros hogares",
    1: "De uso exclusivo de las personas del hogar"
}
df["Forma de disposición del servicio sanitario"] = df["Forma de disposición del servicio sanitario"].replace(uso_servicio_sanitario_dict)

# %%
metodo_eliminacion_basuras_dict = {
    5: "La eliminan de otra forma",
    4: "La queman o entierran",
    3: "La tiran a un patio, lote, zanja o baldío",
    2: "La tiran a un río, quebrada, caño o laguna",
    1: "Por recolección pública o privada"
}
df["Método de eliminación de basuras en el hogar"] = df["Método de eliminación de basuras en el hogar"].replace(metodo_eliminacion_basuras_dict)

# %%
origen_agua_dict = {
    10: "Agua embotellada o en bolsa",
    9: "Aguatero",
    8: "Carro tanque",
    7: "De pila pública",
    6: "Río, quebrada, nacimiento o manantial",
    5: "Aguas lluvias",
    4: "De pozo sin bomba, aljibe, jagüey o barreno",
    3: "De pozo con bomba",
    2: "De otra fuente por tubería",
    1: "De acueducto por tubería"
}
df["Fuente principal de agua para consumo humano"] = df["Fuente principal de agua para consumo humano"].replace(origen_agua_dict)

# %%
lugar_preparacion_dict = {
    6: "En ninguna parte, no preparan alimentos",
    5: "En un patio, corredor, enramada, al aire libre",
    4: "En una sala comedor sin lavaplatos",
    3: "En una sala comedor con lavaplatos",
    2: "En un cuarto usado también para dormir",
    1: "En un cuarto usado solo para cocinar"
}
df["Lugar donde se preparan los alimentos"] = df["Lugar donde se preparan los alimentos"].replace(lugar_preparacion_dict)

# %%
energia_cocinar_dict = {
    7: "Materiales de desecho",
    6: "Carbón mineral",
    5: "Leña, madera o carbón de leña",
    4: "Gas propano en cilindro o pipeta",
    3: "Gas natural conectado a red pública",
    2: "Petróleo, gasolina, kerosene, alcohol",
    1: "Electricidad"
}
df["Tipo de energía o combustible usado para cocinar"] = df["Tipo de energía o combustible usado para cocinar"].replace(energia_cocinar_dict)

# %%
ocupacion_vivienda_dict = {
    7: "Otra",
    6: "Propiedad colectiva",
    5: "Posesión sin título",
    4: "En usufructo",
    3: "En arriendo o subarriendo",
    2: "Propia, la están pagando",
    1: "Propia, totalmente pagada"
}
df["Tipo de ocupación de la vivienda"] = df["Tipo de ocupación de la vivienda"].replace(ocupacion_vivienda_dict)

# %%
producto_financiero_labels = {
    "Uso de productos financieros (1)": "Cuenta corriente",
    "Uso de productos financieros (2)": "Cuenta de ahorros",
    "Uso de productos financieros (3)": "CDT",
    "Uso de productos financieros (4)": "Préstamo vivienda",
    "Uso de productos financieros (5)": "Préstamo vehículo",
    "Uso de productos financieros (6)": "Libre inversión",
    "Uso de productos financieros (7)": "Tarjeta de crédito",
    "Uso de productos financieros (8)": "Otro",
    "Uso de productos financieros (9)": "Ninguno",
    "Uso de productos financieros (10)": "No sabe"
}

# %%
def combinar_productos_financieros(row):
    productos = [
        nombre for col, nombre in producto_financiero_labels.items()
        if col in row and row[col] == 1
    ]
    return " + ".join(productos) if productos else "Ninguno"

df["Uso de productos financieros (consolidado)"] = df.apply(combinar_productos_financieros, axis=1)

# %%
cols_productos_financieros = [
    "Uso de productos financieros (1)",
    "Uso de productos financieros (2)",
    "Uso de productos financieros (3)",
    "Uso de productos financieros (4)",
    "Uso de productos financieros (5)",
    "Uso de productos financieros (6)",
    "Uso de productos financieros (7)",
    "Uso de productos financieros (8)",
    "Uso de productos financieros (9)",
    "Uso de productos financieros (10)", 
    "Especificación del tipo de ocupación"
]
df = df.drop(columns=cols_productos_financieros)

# %%
for col in df.columns:
    if is_string_dtype(df[col]):
        print(f"{col}: 🔤 string")
    elif is_float_dtype(df[col]):
        print(f"{col}: 🔢 float")
    elif is_integer_dtype(df[col]):
        print(f"{col}: 🔢 integer")
    elif is_bool_dtype(df[col]):
        print(f"{col}: ✅ boolean")
    elif is_categorical_dtype(df[col]):
        print(f"{col}: 🧩 category")
    elif is_object_dtype(df[col]):
        print(f"{col}: 📦 object (possibly mixed or string)")
    else:
        print(f"{col}: ❓ unknown ({df[col].dtype})")
# Out:
# key_ninos: 🔢 integer
# primary_key: 🔢 integer
# Periodo de referencia: 🔢 integer
# Código del periodo: 🔢 integer
# Número de directorio del hogar: 🔢 integer
# Departamento: 🔤 string
# Sexo al nacer: 🔤 string
# Edad en años cumplidos: 🔢 integer
# Mes de nacimiento: 🔢 float
# Año de nacimiento: 🔢 float
# Parentesco con el jefe(a) del hogar: 📦 object (possibly mixed or string)
# ¿Madre reside en el hogar?: 📦 object (possibly mixed or string)
# ¿Padre reside en el hogar?: 📦 object (possibly mixed or string)
# ¿Se considera campesino(a)?: 📦 object (possibly mixed or string)
# ¿Alguna vez fue campesino(a)?: 📦 object (possibly mixed or string)
# ¿Su comunidad es campesina?: 📦 object (possibly mixed or string)
# Autoidentificación étnica: 🔤 string
# Estado civil: 📦 object (possibly mixed or string)
# ¿Cónyuge reside en el hogar?: 📦 object (possibly mixed or string)
# COVID: estuvo enfermo(a): 📦 object (possibly mixed or string)
# ...

# %%
object_columns = [col for col in df.columns if is_object_dtype(df[col])]

print("📦 Columns with dtype 'object' (possibly mixed or string):")
for col in object_columns:
    print(f"- {col}")
# Out:
# 📦 Columns with dtype 'object' (possibly mixed or string):
# - Departamento
# - Sexo al nacer
# - Parentesco con el jefe(a) del hogar
# - ¿Madre reside en el hogar?
# - ¿Padre reside en el hogar?
# - ¿Se considera campesino(a)?
# - ¿Alguna vez fue campesino(a)?
# - ¿Su comunidad es campesina?
# - Autoidentificación étnica
# - Estado civil
# - ¿Cónyuge reside en el hogar?
# - COVID: estuvo enfermo(a)
# - COVID: dificultad con alimentos/productos
# - COVID: dificultad con pagos/deudas
# - COVID: reducción de ingresos
# - COVID: sin trabajo o sin poder buscarlo
# - COVID: suspensión contrato sin paga
# - COVID: pérdida de trabajo o ingresos
# - COVID: suspensión de clases
# - COVID: malestar emocional
# - COVID: otra dificultad
# - COVID: sin dificultades
# - COVID: otra dificultad - detalle
# - Afiliación sistema de salud
# - Régimen de salud
# - Quién paga la afiliación
# - ¿Sabe leer y escribir?
# - ¿Asiste actualmente a clase?
# - Tipo de institución educativa
# ...

# %%
df["Parentesco con el jefe(a) del hogar"] = df["Parentesco con el jefe(a) del hogar"].astype(str)

# %%
cols_to_convert = [
    "Departamento",
    "Sexo al nacer",
    "Parentesco con el jefe(a) del hogar",
    "¿Madre reside en el hogar?",
    "¿Padre reside en el hogar?",
    "¿Se considera campesino(a)?",
    "¿Alguna vez fue campesino(a)?",
    "¿Su comunidad es campesina?",
    "Autoidentificación étnica",
    "Estado civil",
    "¿Cónyuge reside en el hogar?",
    "COVID: estuvo enfermo(a)",
    "COVID: dificultad con alimentos/productos",
    "COVID: dificultad con pagos/deudas",
    "COVID: reducción de ingresos",
    "COVID: sin trabajo o sin poder buscarlo",
    "COVID: suspensión contrato sin paga",
    "COVID: pérdida de trabajo o ingresos",
    "COVID: suspensión de clases",
    "COVID: malestar emocional",
    "COVID: otra dificultad",
    "COVID: sin dificultades",
    "COVID: otra dificultad - detalle",
    "Afiliación sistema de salud",
    "Régimen de salud",
    "Quién paga la afiliación",
    "¿Sabe leer y escribir?",
    "¿Asiste actualmente a clase?",
    "Tipo de institución educativa",
    "Condición de discapacidad",
    "Pertenencia a comunidad campesina",
    "Tipo de vivienda",
    "Material predominante de las paredes exteriores",
    "Material predominante del piso",
    "Disponibilidad de energía eléctrica",
    "Estrato para tarifa de electricidad",
    "Disponibilidad de gas natural por red pública",
    "Disponibilidad de alcantarillado",
    "Disponibilidad de recolección de basuras",
    "Disponibilidad de acueducto",
    "Tipo de servicio sanitario que utiliza el hogar",
    "Forma de disposición del servicio sanitario",
    "Método de eliminación de basuras en el hogar",
    "Fuente principal de agua para consumo humano",
    "Lugar donde se preparan los alimentos",
    "Tipo de energía o combustible usado para cocinar",
    "Tipo de ocupación de la vivienda",
    "Especificación del tipo de ocupación"
]

# Convertir a string solo si la columna existe en el DataFrame
for col in cols_to_convert:
    if col in df.columns:
        df[col] = df[col].astype("string")

# %%
df = df.replace('<NA>', np.nan)

# %%
df
# Out:
#         key_ninos  primary_key  Periodo de referencia  Código del periodo  \
# 0       730906013     73090601               20230104                2023
# 1       730906414     73090641               20230104                2023
# 2       730906812     73090681               20230104                2023
# 3       730906913     73090691               20230104                2023
# 4       730907013     73090701               20230104                2023
# ...           ...          ...                    ...                 ...
# 176343  756731615     75673161               20230939                2023
# 176344  756731814     75673181               20230939                2023
# 176345  756731815     75673181               20230939                2023
# 176346  756731913     75673191               20230939                2023
# 176347  756732313     75673231               20230937                2023
#
#         Número de directorio del hogar     Departamento Sexo al nacer  \
# ...

# %%
df.to_parquet(r"C:\Users\ASUS\Downloads\finallabeled.parquet", index=False, engine="pyarrow")  # or fastparquet
