# %%
import pandas as pd

# %%
df = pd.read_parquet(r'C:\Users\ASUS\Downloads\finallabeled_.parquet')

# %%
# Replace missing values
for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:  # Numerical columns
        df[column].fillna(df[column].quantile(0.75), inplace=True)
    elif df[column].dtype == 'string' or df[column].dtype == 'object':  # Categorical columns
        df[column].fillna(df[column].mode()[0], inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\318582866.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].quantile(0.75), inplace=True)

# %%
# Display columns with their null values count
null_values = df.isnull().sum()
print(null_values)
# Out:
# key_ninos                                             0
# primary_key                                           0
# Departamento                                          0
# Sexo al nacer                                         0
# Edad en años cumplidos                                0
#                                                      ..
# Tipo de energía o combustible usado para cocinar      0
# Tipo de ocupación de la vivienda                      0
# Valor estimado de arriendo si se tuviera que pagar    0
# Total de personas en el hogar                         0
# trabajo_infantil                                      0
# Length: 64, dtype: int64

# %%
df_trabajo = df.copy()

# %%
df = df.drop(columns=['trabajo_infantil'])

# %%
df
# Out:
#         key_ninos  primary_key     Departamento Sexo al nacer  \
# 0       730906013     73090601     Cundinamarca         Mujer
# 1       730906414     73090641        Risaralda         Mujer
# 2       730906812     73090681        Risaralda         Mujer
# 3       730906913     73090691        Risaralda        Hombre
# 4       730907013     73090701        Risaralda         Mujer
# ...           ...          ...              ...           ...
# 176343  756731615     75673161  Valle del Cauca         Mujer
# 176344  756731814     75673181           Caldas        Hombre
# 176345  756731815     75673181           Caldas         Mujer
# 176346  756731913     75673191        Antioquia        Hombre
# 176347  756732313     75673231  Valle del Cauca        Hombre
#
#         Edad en años cumplidos Parentesco con el jefe(a) del hogar  \
# 0                            7                Hijo(a), hijastro(a)
# 1                           13                Hijo(a), hijastro(a)
# 2                           17                Hijo(a), hijastro(a)
# 3                           13                          Trabajador
# 4                           17                Hijo(a), hijastro(a)
# ...                        ...                                 ...
# 176343                       5                          Trabajador
# 176344                      16                Hijo(a), hijastro(a)
# 176345                       9                Hijo(a), hijastro(a)
# 176346                      10                Hijo(a), hijastro(a)
# 176347                       9                Hijo(a), hijastro(a)
#
#        ¿Madre reside en el hogar? ¿Padre reside en el hogar?  \
# 0                              Sí                         No
# 1                              Sí                         Sí
# 2                              Sí                         No
# 3                              Sí                         No
# 4                              Sí                         Sí
# ...                           ...                        ...
# 176343                         Sí                         Sí
# 176344                         Sí                         No
# 176345                         Sí                         No
# 176346                         Sí                         Sí
# 176347                         Sí                         Sí
#
#        ¿Se considera campesino(a)? ¿Alguna vez fue campesino(a)?  ...  \
# 0                               Sí                            No  ...
# 1                               Sí                            No  ...
# 2                               Sí                            No  ...
# 3                               No                            No  ...
# 4                               Sí                            No  ...
# ...                            ...                           ...  ...
# 176343                          No                            No  ...
# 176344                          Sí                            No  ...
# 176345                          Sí                            No  ...
# 176346                          Sí                            No  ...
# 176347                          No                            No  ...
#
#        Número de cuartos usados para dormir  \
# 0                                       2.0
# 1                                       3.0
# 2                                       1.0
# 3                                       2.0
# 4                                       1.0
# ...                                     ...
# 176343                                  3.0
# 176344                                  4.0
# 176345                                  4.0
# 176346                                  3.0
# 176347                                  3.0
#
#        Tipo de servicio sanitario que utiliza el hogar  \
# 0                   Inodoro conectado a alcantarillado
# 1                     Inodoro conectado a pozo séptico
# 2                     Inodoro conectado a pozo séptico
# 3                     Inodoro conectado a pozo séptico
# 4                     Inodoro conectado a pozo séptico
# ...                                                ...
# 176343              Inodoro conectado a alcantarillado
# 176344                            Inodoro sin conexión
# 176345                            Inodoro sin conexión
# 176346              Inodoro conectado a alcantarillado
# 176347              Inodoro conectado a alcantarillado
#
#        Forma de disposición del servicio sanitario  \
# 0       De uso exclusivo de las personas del hogar
# 1       De uso exclusivo de las personas del hogar
# 2       De uso exclusivo de las personas del hogar
# 3       De uso exclusivo de las personas del hogar
# 4       De uso exclusivo de las personas del hogar
# ...                                            ...
# 176343  De uso exclusivo de las personas del hogar
# 176344  De uso exclusivo de las personas del hogar
# 176345  De uso exclusivo de las personas del hogar
# 176346  De uso exclusivo de las personas del hogar
# 176347  De uso exclusivo de las personas del hogar
#
#        Método de eliminación de basuras en el hogar  \
# 0                 Por recolección pública o privada
# 1                 Por recolección pública o privada
# 2                 Por recolección pública o privada
# 3                 Por recolección pública o privada
# 4                 Por recolección pública o privada
# ...                                             ...
# 176343            Por recolección pública o privada
# 176344            Por recolección pública o privada
# 176345            Por recolección pública o privada
# 176346            Por recolección pública o privada
# 176347            Por recolección pública o privada
#
#        Fuente principal de agua para consumo humano  \
# 0                          De acueducto por tubería
# 1                          De acueducto por tubería
# 2                          De acueducto por tubería
# 3                          De acueducto por tubería
# 4                          De acueducto por tubería
# ...                                             ...
# 176343                     De acueducto por tubería
# 176344                   De otra fuente por tubería
# 176345                   De otra fuente por tubería
# 176346                     De acueducto por tubería
# 176347                     De acueducto por tubería
#
#        Lugar donde se preparan los alimentos  \
# 0       En un cuarto usado solo para cocinar
# 1       En un cuarto usado solo para cocinar
# 2       En un cuarto usado solo para cocinar
# 3         En una sala comedor con lavaplatos
# 4       En un cuarto usado solo para cocinar
# ...                                      ...
# 176343  En un cuarto usado solo para cocinar
# 176344  En un cuarto usado solo para cocinar
# 176345  En un cuarto usado solo para cocinar
# 176346  En un cuarto usado solo para cocinar
# 176347  En un cuarto usado solo para cocinar
#
#        Tipo de energía o combustible usado para cocinar  \
# 0                      Gas propano en cilindro o pipeta
# 1                   Gas natural conectado a red pública
# 2                   Gas natural conectado a red pública
# 3                   Gas natural conectado a red pública
# 4                   Gas natural conectado a red pública
# ...                                                 ...
# 176343              Gas natural conectado a red pública
# 176344                 Gas propano en cilindro o pipeta
# 176345                 Gas propano en cilindro o pipeta
# 176346              Gas natural conectado a red pública
# 176347              Gas natural conectado a red pública
#
#        Tipo de ocupación de la vivienda  \
# 0             En arriendo o subarriendo
# 1             En arriendo o subarriendo
# 2                          En usufructo
# 3             Propia, totalmente pagada
# 4             En arriendo o subarriendo
# ...                                 ...
# 176343        Propia, totalmente pagada
# 176344        Propia, totalmente pagada
# 176345        Propia, totalmente pagada
# 176346        En arriendo o subarriendo
# 176347        En arriendo o subarriendo
#
#        Valor estimado de arriendo si se tuviera que pagar  \
# 0                                           621140.830428
# 1                                           621140.830428
# 2                                           350000.000000
# 3                                           150000.000000
# 4                                           621140.830428
# ...                                                   ...
# 176343                                          98.000000
# 176344                                      500000.000000
# 176345                                      500000.000000
# 176346                                      621140.830428
# 176347                                      621140.830428
#
#        Total de personas en el hogar
# 0                                3.0
# 1                                5.0
# 2                                2.0
# 3                                5.0
# 4                                5.0
# ...                              ...
# 176343                           5.0
# 176344                           7.0
# 176345                           7.0
# 176346                           3.0
# 176347                           4.0
#
# [176348 rows x 63 columns]

# %%
df.columns
# Out:
# Index(['key_ninos', 'primary_key', 'Departamento', 'Sexo al nacer',
#        'Edad en años cumplidos', 'Parentesco con el jefe(a) del hogar',
#        '¿Madre reside en el hogar?', '¿Padre reside en el hogar?',
#        '¿Se considera campesino(a)?', '¿Alguna vez fue campesino(a)?',
#        '¿Su comunidad es campesina?', 'Autoidentificación étnica',
#        'Estado civil', '¿Cónyuge reside en el hogar?',
#        'COVID: estuvo enfermo(a)', 'COVID: dificultad con alimentos/productos',
#        'COVID: dificultad con pagos/deudas', 'COVID: reducción de ingresos',
#        'COVID: sin trabajo o sin poder buscarlo',
#        'COVID: suspensión contrato sin paga',
#        'COVID: pérdida de trabajo o ingresos', 'COVID: suspensión de clases',
#        'COVID: malestar emocional', 'COVID: otra dificultad',
#        'COVID: sin dificultades', 'Afiliación sistema de salud',
#        'Régimen de salud', 'Dificultad auditiva', 'Dificultad para hablar',
#        'Dificultad visual', 'Dificultad motriz', 'Dificultad en manos',
#        'Dificultad cognitiva', 'Dificultad en autocuidado',
#        'Dificultad para relacionarse', '¿Sabe leer y escribir?',
#        '¿Asiste actualmente a clase?', 'Tipo de institución educativa',
#        'Nivel educativo y grado aprobado', 'Condición de discapacidad',
#        'Pertenencia a comunidad campesina', 'Tipo de vivienda',
#        'Material predominante de las paredes exteriores',
#        'Material predominante del piso', 'Disponibilidad de energía eléctrica',
#        'Estrato para tarifa de electricidad',
#        'Disponibilidad de gas natural por red pública',
#        'Disponibilidad de alcantarillado',
#        'Disponibilidad de recolección de basuras',
#        'Frecuencia de recolección de basura (veces por semana)',
#        'Disponibilidad de acueducto', 'Cantidad de hogares en la vivienda',
#        'Número total de cuartos disponibles en el hogar',
#        'Número de cuartos usados para dormir',
#        'Tipo de servicio sanitario que utiliza el hogar',
#        'Forma de disposición del servicio sanitario',
#        'Método de eliminación de basuras en el hogar',
#        'Fuente principal de agua para consumo humano',
#        'Lugar donde se preparan los alimentos',
#        'Tipo de energía o combustible usado para cocinar',
#        'Tipo de ocupación de la vivienda',
#        'Valor estimado de arriendo si se tuviera que pagar',
#        'Total de personas en el hogar'],
#       dtype='object')

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.replace('\n', '_')             # Reemplaza saltos de línea por espacios
    .str.replace(r'\(a\)', 'a', regex=True)  # Opcional: limpia paréntesis si están mal
    .str.replace(r'\s+', '_', regex=True)    # Reduce múltiples espacios a uno solo
)

# %%
# Limpiar los datos dentro de las columnas
df = df.applymap(lambda x: str(x).strip().replace(" ", "_").replace("¿", "").replace("?", "").replace(":", "").replace(",", "").replace("(", "").replace(")", "").replace("/", "_") if isinstance(x, str) else x)

# Mostrar el DataFrame limpio
print(df)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18796\228302889.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: str(x).strip().replace(" ", "_").replace("¿", "").replace("?", "").replace(":", "").replace(",", "").replace("(", "").replace(")", "").replace("/", "_") if isinstance(x, str) else x)
#         key_ninos  primary_key     Departamento Sexo_al_nacer  \
# 0       730906013     73090601     Cundinamarca         Mujer
# 1       730906414     73090641        Risaralda         Mujer
# 2       730906812     73090681        Risaralda         Mujer
# 3       730906913     73090691        Risaralda        Hombre
# 4       730907013     73090701        Risaralda         Mujer
# ...           ...          ...              ...           ...
# 176343  756731615     75673161  Valle_del_Cauca         Mujer
# 176344  756731814     75673181           Caldas        Hombre
# 176345  756731815     75673181           Caldas         Mujer
# 176346  756731913     75673191        Antioquia        Hombre
# 176347  756732313     75673231  Valle_del_Cauca        Hombre
#
#         Edad_en_años_cumplidos Parentesco_con_el_jefea_del_hogar  \
# 0                            7                   Hijoa_hijastroa
# 1                           13                   Hijoa_hijastroa
# 2                           17                   Hijoa_hijastroa
# 3                           13                        Trabajador
# 4                           17                   Hijoa_hijastroa
# ...                        ...                               ...
# 176343                       5                        Trabajador
# 176344                      16                   Hijoa_hijastroa
# 176345                       9                   Hijoa_hijastroa
# 176346                      10                   Hijoa_hijastroa
# 176347                       9                   Hijoa_hijastroa
#
#        ¿Madre_reside_en_el_hogar? ¿Padre_reside_en_el_hogar?  \
# 0                              Sí                         No
# 1                              Sí                         Sí
# 2                              Sí                         No
# 3                              Sí                         No
# 4                              Sí                         Sí
# ...                           ...                        ...
# 176343                         Sí                         Sí
# 176344                         Sí                         No
# 176345                         Sí                         No
# 176346                         Sí                         Sí
# 176347                         Sí                         Sí
#
#        ¿Se_considera_campesinoa? ¿Alguna_vez_fue_campesinoa?  ...  \
# 0                             Sí                          No  ...
# 1                             Sí                          No  ...
# 2                             Sí                          No  ...
# 3                             No                          No  ...
# 4                             Sí                          No  ...
# ...                          ...                         ...  ...
# 176343                        No                          No  ...
# 176344                        Sí                          No  ...
# 176345                        Sí                          No  ...
# 176346                        Sí                          No  ...
# 176347                        No                          No  ...
#
#        Número_de_cuartos_usados_para_dormir  \
# 0                                       2.0
# 1                                       3.0
# 2                                       1.0
# 3                                       2.0
# 4                                       1.0
# ...                                     ...
# 176343                                  3.0
# 176344                                  4.0
# 176345                                  4.0
# 176346                                  3.0
# 176347                                  3.0
#
#        Tipo_de_servicio_sanitario_que_utiliza_el_hogar  \
# 0                   Inodoro_conectado_a_alcantarillado
# 1                     Inodoro_conectado_a_pozo_séptico
# 2                     Inodoro_conectado_a_pozo_séptico
# 3                     Inodoro_conectado_a_pozo_séptico
# 4                     Inodoro_conectado_a_pozo_séptico
# ...                                                ...
# 176343              Inodoro_conectado_a_alcantarillado
# 176344                            Inodoro_sin_conexión
# 176345                            Inodoro_sin_conexión
# 176346              Inodoro_conectado_a_alcantarillado
# 176347              Inodoro_conectado_a_alcantarillado
#
#        Forma_de_disposición_del_servicio_sanitario  \
# 0       De_uso_exclusivo_de_las_personas_del_hogar
# 1       De_uso_exclusivo_de_las_personas_del_hogar
# 2       De_uso_exclusivo_de_las_personas_del_hogar
# 3       De_uso_exclusivo_de_las_personas_del_hogar
# 4       De_uso_exclusivo_de_las_personas_del_hogar
# ...                                            ...
# 176343  De_uso_exclusivo_de_las_personas_del_hogar
# 176344  De_uso_exclusivo_de_las_personas_del_hogar
# 176345  De_uso_exclusivo_de_las_personas_del_hogar
# 176346  De_uso_exclusivo_de_las_personas_del_hogar
# 176347  De_uso_exclusivo_de_las_personas_del_hogar
#
#        Método_de_eliminación_de_basuras_en_el_hogar  \
# 0                 Por_recolección_pública_o_privada
# 1                 Por_recolección_pública_o_privada
# 2                 Por_recolección_pública_o_privada
# 3                 Por_recolección_pública_o_privada
# 4                 Por_recolección_pública_o_privada
# ...                                             ...
# 176343            Por_recolección_pública_o_privada
# 176344            Por_recolección_pública_o_privada
# 176345            Por_recolección_pública_o_privada
# 176346            Por_recolección_pública_o_privada
# 176347            Por_recolección_pública_o_privada
#
#        Fuente_principal_de_agua_para_consumo_humano  \
# 0                          De_acueducto_por_tubería
# 1                          De_acueducto_por_tubería
# 2                          De_acueducto_por_tubería
# 3                          De_acueducto_por_tubería
# 4                          De_acueducto_por_tubería
# ...                                             ...
# 176343                     De_acueducto_por_tubería
# 176344                   De_otra_fuente_por_tubería
# 176345                   De_otra_fuente_por_tubería
# 176346                     De_acueducto_por_tubería
# 176347                     De_acueducto_por_tubería
#
#        Lugar_donde_se_preparan_los_alimentos  \
# 0       En_un_cuarto_usado_solo_para_cocinar
# 1       En_un_cuarto_usado_solo_para_cocinar
# 2       En_un_cuarto_usado_solo_para_cocinar
# 3         En_una_sala_comedor_con_lavaplatos
# 4       En_un_cuarto_usado_solo_para_cocinar
# ...                                      ...
# 176343  En_un_cuarto_usado_solo_para_cocinar
# 176344  En_un_cuarto_usado_solo_para_cocinar
# 176345  En_un_cuarto_usado_solo_para_cocinar
# 176346  En_un_cuarto_usado_solo_para_cocinar
# 176347  En_un_cuarto_usado_solo_para_cocinar
#
#        Tipo_de_energía_o_combustible_usado_para_cocinar  \
# 0                      Gas_propano_en_cilindro_o_pipeta
# 1                   Gas_natural_conectado_a_red_pública
# 2                   Gas_natural_conectado_a_red_pública
# 3                   Gas_natural_conectado_a_red_pública
# 4                   Gas_natural_conectado_a_red_pública
# ...                                                 ...
# 176343              Gas_natural_conectado_a_red_pública
# 176344                 Gas_propano_en_cilindro_o_pipeta
# 176345                 Gas_propano_en_cilindro_o_pipeta
# 176346              Gas_natural_conectado_a_red_pública
# 176347              Gas_natural_conectado_a_red_pública
#
#        Tipo_de_ocupación_de_la_vivienda  \
# 0             En_arriendo_o_subarriendo
# 1             En_arriendo_o_subarriendo
# 2                          En_usufructo
# 3              Propia_totalmente_pagada
# 4             En_arriendo_o_subarriendo
# ...                                 ...
# 176343         Propia_totalmente_pagada
# 176344         Propia_totalmente_pagada
# 176345         Propia_totalmente_pagada
# 176346        En_arriendo_o_subarriendo
# 176347        En_arriendo_o_subarriendo
#
#        Valor_estimado_de_arriendo_si_se_tuviera_que_pagar  \
# 0                                           621140.830428
# 1                                           621140.830428
# 2                                           350000.000000
# 3                                           150000.000000
# 4                                           621140.830428
# ...                                                   ...
# 176343                                          98.000000
# 176344                                      500000.000000
# 176345                                      500000.000000
# 176346                                      621140.830428
# 176347                                      621140.830428
#
#        Total_de_personas_en_el_hogar
# 0                                3.0
# 1                                5.0
# 2                                2.0
# 3                                5.0
# 4                                5.0
# ...                              ...
# 176343                           5.0
# 176344                           7.0
# 176345                           7.0
# 176346                           3.0
# 176347                           4.0
#
# [176348 rows x 63 columns]

# %%
# Identificar columnas categóricas
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

# Diccionario para almacenar los mapeos de categorías
label_maps = {}

# Aplicar label encoding y guardar los mapeos
for col in categorical_cols:
    df[col] = df[col].astype('category', 'object')
    label_maps[col] = dict(enumerate(df[col].cat.categories))
    df[col] = df[col].cat.codes

# Mostrar el DataFrame codificado
print(df)

# Mostrar los mapeos
print("\nMapeos de categorías:")
for col, mapping in label_maps.items():
    print(f"{col}: {mapping}")
# Out:
#         key_ninos  primary_key  Departamento  Sexo_al_nacer  \
# 0       730906013     73090601            14              1
# 1       730906414     73090641            26              1
# 2       730906812     73090681            26              1
# 3       730906913     73090691            26              0
# 4       730907013     73090701            26              1
# ...           ...          ...           ...            ...
# 176343  756731615     75673161            30              1
# 176344  756731814     75673181             8              0
# 176345  756731815     75673181             8              1
# 176346  756731913     75673191             1              0
# 176347  756732313     75673231            30              0
#
#         Edad_en_años_cumplidos  Parentesco_con_el_jefea_del_hogar  \
# 0                            7                                  2
# 1                           13                                  2
# 2                           17                                  2
# 3                           13                                 11
# 4                           17                                  2
# ...                        ...                                ...
# 176343                       5                                 11
# 176344                      16                                  2
# 176345                       9                                  2
# 176346                      10                                  2
# 176347                       9                                  2
#
#         ¿Madre_reside_en_el_hogar?  ¿Padre_reside_en_el_hogar?  \
# 0                                2                           1
# 1                                2                           2
# 2                                2                           1
# 3                                2                           1
# 4                                2                           2
# ...                            ...                         ...
# 176343                           2                           2
# 176344                           2                           1
# 176345                           2                           1
# 176346                           2                           2
# 176347                           2                           2
#
#         ¿Se_considera_campesinoa?  ¿Alguna_vez_fue_campesinoa?  ...  \
# 0                               1                            0  ...
# 1                               1                            0  ...
# 2                               1                            0  ...
# 3                               0                            0  ...
# 4                               1                            0  ...
# ...                           ...                          ...  ...
# 176343                          0                            0  ...
# 176344                          1                            0  ...
# 176345                          1                            0  ...
# 176346                          1                            0  ...
# 176347                          0                            0  ...
#
#         Número_de_cuartos_usados_para_dormir  \
# 0                                        2.0
# 1                                        3.0
# 2                                        1.0
# 3                                        2.0
# 4                                        1.0
# ...                                      ...
# 176343                                   3.0
# 176344                                   4.0
# 176345                                   4.0
# 176346                                   3.0
# 176347                                   3.0
#
#         Tipo_de_servicio_sanitario_que_utiliza_el_hogar  \
# 0                                                     1
# 1                                                     2
# 2                                                     2
# 3                                                     2
# 4                                                     2
# ...                                                 ...
# 176343                                                1
# 176344                                                3
# 176345                                                3
# 176346                                                1
# 176347                                                1
#
#         Forma_de_disposición_del_servicio_sanitario  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 1
# 4                                                 1
# ...                                             ...
# 176343                                            1
# 176344                                            1
# 176345                                            1
# 176346                                            1
# 176347                                            1
#
#         Método_de_eliminación_de_basuras_en_el_hogar  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
# ...                                              ...
# 176343                                             4
# 176344                                             4
# 176345                                             4
# 176346                                             4
# 176347                                             4
#
#         Fuente_principal_de_agua_para_consumo_humano  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
# ...                                              ...
# 176343                                             4
# 176344                                             5
# 176345                                             5
# 176346                                             4
# 176347                                             4
#
#         Lugar_donde_se_preparan_los_alimentos  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           4
# 4                                           1
# ...                                       ...
# 176343                                      1
# 176344                                      1
# 176345                                      1
# 176346                                      1
# 176347                                      1
#
#         Tipo_de_energía_o_combustible_usado_para_cocinar  \
# 0                                                      3
# 1                                                      2
# 2                                                      2
# 3                                                      2
# 4                                                      2
# ...                                                  ...
# 176343                                                 2
# 176344                                                 3
# 176345                                                 3
# 176346                                                 2
# 176347                                                 2
#
#         Tipo_de_ocupación_de_la_vivienda  \
# 0                                      0
# 1                                      0
# 2                                      1
# 3                                      5
# 4                                      0
# ...                                  ...
# 176343                                 5
# 176344                                 5
# 176345                                 5
# 176346                                 0
# 176347                                 0
#
#         Valor_estimado_de_arriendo_si_se_tuviera_que_pagar  \
# 0                                           621140.830428
# 1                                           621140.830428
# 2                                           350000.000000
# 3                                           150000.000000
# 4                                           621140.830428
# ...                                                   ...
# 176343                                          98.000000
# 176344                                      500000.000000
# 176345                                      500000.000000
# 176346                                      621140.830428
# 176347                                      621140.830428
#
#         Total_de_personas_en_el_hogar
# 0                                 3.0
# 1                                 5.0
# 2                                 2.0
# 3                                 5.0
# 4                                 5.0
# ...                               ...
# 176343                            5.0
# 176344                            7.0
# 176345                            7.0
# 176346                            3.0
# 176347                            4.0
#
# [176348 rows x 63 columns]
#
# Mapeos de categorías:
# Departamento: {0: 'Amazonas', 1: 'Antioquia', 2: 'Arauca', 3: 'Archipiélago_de_San_Andrés_Providencia_y_Santa_Catalina', 4: 'Atlántico', 5: 'Bogotá_D.C.', 6: 'Bolívar', 7: 'Boyacá', 8: 'Caldas', 9: 'Caquetá', 10: 'Casanare', 11: 'Cauca', 12: 'Cesar', 13: 'Chocó', 14: 'Cundinamarca', 15: 'Córdoba', 16: 'Guainía', 17: 'Guaviare', 18: 'Huila', 19: 'La_Guajira', 20: 'Magdalena', 21: 'Meta', 22: 'Nariño', 23: 'Norte_de_Santander', 24: 'Putumayo', 25: 'Quindío', 26: 'Risaralda', 27: 'Santander', 28: 'Sucre', 29: 'Tolima', 30: 'Valle_del_Cauca', 31: 'Vaupés', 32: 'Vichada'}
# Sexo_al_nacer: {0: 'Hombre', 1: 'Mujer'}
# Parentesco_con_el_jefea_del_hogar: {0: 'Empleadoa_del_servicio_doméstico_y_sus_parientes', 1: 'Hermanoa', 2: 'Hijoa_hijastroa', 3: 'Jefea_del_hogar', 4: 'Nietoa', 5: 'Otro_miembro', 6: 'Otro_no_pariente', 7: 'Otro_pariente', 8: 'Pareja_esposoa_cónyuge_compañeroa', 9: 'Pensionista', 10: 'Sobrinoa', 11: 'Trabajador', 12: 'Yerno___Nuera'}
# ¿Madre_reside_en_el_hogar?: {0: 'Fallecida', 1: 'No', 2: 'Sí'}
# ¿Padre_reside_en_el_hogar?: {0: 'Fallecido', 1: 'No', 2: 'Sí'}
# ¿Se_considera_campesinoa?: {0: 'No', 1: 'Sí'}
# ¿Alguna_vez_fue_campesinoa?: {0: 'No', 1: 'Sí'}
# ¿Su_comunidad_es_campesina?: {0: 'No', 1: 'Sí'}
# Autoidentificación_étnica: {0: 'Gitanoa_Rom', 1: 'Indígena', 2: 'Negroa_mulatoa_afrodescendiente_afrocolombianoa', 3: 'Ninguno_de_los_anteriores', 4: 'Palenqueroa_de_San_Basilio', 5: 'Raizal_del_archipiélago_de_San_Andrés_Providencia_y_Santa_Catalina'}
# Estado_civil: {0: 'Está_casadoa', 1: 'Está_separadoa_o_divorciadoa', 2: 'Está_solteroa', 3: 'Está_viudoa', 4: 'No_está_casadoa_y_vive_en_pareja_hace_dos_años_o_más', 5: 'No_está_casadoa_y_vive_en_pareja_hace_menos_de_dos_años'}
# ¿Cónyuge_reside_en_el_hogar?: {0: 'No', 1: 'Sí'}
# COVID:_estuvo_enfermoa: {0: 'No', 1: 'Sí'}
# COVID:_dificultad_con_alimentos/productos: {0: 'No', 1: 'Sí'}
# COVID:_dificultad_con_pagos/deudas: {0: 'No', 1: 'Sí'}
# COVID:_reducción_de_ingresos: {0: 'No', 1: 'Sí'}
# COVID:_sin_trabajo_o_sin_poder_buscarlo: {0: 'No', 1: 'Sí'}
# COVID:_suspensión_contrato_sin_paga: {0: 'No', 1: 'Sí'}
# COVID:_pérdida_de_trabajo_o_ingresos: {0: 'No', 1: 'Sí'}
# COVID:_suspensión_de_clases: {0: 'No', 1: 'Sí'}
# COVID:_malestar_emocional: {0: 'No', 1: 'Sí'}
# COVID:_otra_dificultad: {0: 'No', 1: 'Sí'}
# COVID:_sin_dificultades: {0: 'No', 1: 'Sí'}
# Afiliación_sistema_de_salud: {0: 'No', 1: 'Sí'}
# Régimen_de_salud: {0: 'Contributivo_eps', 1: 'Especial__fuerzas_armadas_ecopetrol_universidades_públicas', 2: 'No_sabe_no_informa', 3: 'Subsidiado_eps-s'}
# Dificultad_auditiva: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# Dificultad_para_hablar: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# Dificultad_visual: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# Dificultad_motriz: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# Dificultad_en_manos: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# Dificultad_cognitiva: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# Dificultad_en_autocuidado: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# Dificultad_para_relacionarse: {0: 'No_aplica', 1: 'No_tiene_ninguna_dificultad', 2: 'Tiene_alguna_dificultad', 3: 'Tiene_mucha_dificultad'}
# ¿Sabe_leer_y_escribir?: {0: 'No', 1: 'Sí'}
# ¿Asiste_actualmente_a_clase?: {0: 'No', 1: 'Sí'}
# Tipo_de_institución_educativa: {0: 'Privada', 1: 'Pública'}
# Condición_de_discapacidad: {0: 'No', 1: 'Sí'}
# Pertenencia_a_comunidad_campesina: {0: '9.0', 1: 'No', 2: 'Sí'}
# Tipo_de_vivienda: {0: 'Apartamento', 1: 'Casa', 2: 'Cuartos_en_inquilinato', 3: 'Cuartos_en_otro_tipo_de_estructura', 4: 'Otra_vivienda_carpa_vagón_embarcación_cueva_refugio_natural_etc.', 5: 'Vivienda_indígena'}
# Material_predominante_de_las_paredes_exteriores: {0: 'Adobe_o_tapia_pisada', 1: 'Bahareque', 2: 'Caña_esterilla_otro_tipo_de_material_vegetal', 3: 'Guadua', 4: 'Ladrillo_bloque_material_prefabricado_piedra', 5: 'Madera_burda_tabla_tablón', 6: 'Madera_pulida', 7: 'Sin_paredes', 8: 'Zinc_tela_cartón_latas_desechos_plástico'}
# Material_predominante_del_piso: {0: 'Adobe_o_tapia_pisada', 1: 'Bahareque', 2: 'Caña_esterilla_otro_tipo_de_material_vegetal', 3: 'Guadua', 4: 'Ladrillo_bloque_material_prefabricado_piedra', 5: 'Madera_burda_tabla_tablón', 6: 'Madera_pulida'}
# Disponibilidad_de_energía_eléctrica: {0: 'No', 1: 'Sí'}
# Estrato_para_tarifa_de_electricidad: {0: 'Alto', 1: 'Bajo', 2: 'Bajo_-_bajo', 3: 'Conexión_pirata', 4: 'Medio', 5: 'Medio_-_alto', 6: 'Medio_-_bajo', 7: 'No_sabe_o_cuenta_con_planta_eléctrica'}
# Disponibilidad_de_gas_natural_por_red_pública: {0: 'No', 1: 'Sí'}
# Disponibilidad_de_alcantarillado: {0: 'No', 1: 'Sí'}
# Disponibilidad_de_recolección_de_basuras: {0: 'No', 1: 'Sí'}
# Disponibilidad_de_acueducto: {0: 'No', 1: 'Sí'}
# Tipo_de_servicio_sanitario_que_utiliza_el_hogar: {0: 'Bajamar', 1: 'Inodoro_conectado_a_alcantarillado', 2: 'Inodoro_conectado_a_pozo_séptico', 3: 'Inodoro_sin_conexión', 4: 'Letrina', 5: 'No_tiene_servicio_sanitario'}
# Forma_de_disposición_del_servicio_sanitario: {0: 'Compartido_con_personas_de_otros_hogares', 1: 'De_uso_exclusivo_de_las_personas_del_hogar'}
# Método_de_eliminación_de_basuras_en_el_hogar: {0: 'La_eliminan_de_otra_forma', 1: 'La_queman_o_entierran', 2: 'La_tiran_a_un_patio_lote_zanja_o_baldío', 3: 'La_tiran_a_un_río_quebrada_caño_o_laguna', 4: 'Por_recolección_pública_o_privada'}
# Fuente_principal_de_agua_para_consumo_humano: {0: 'Agua_embotellada_o_en_bolsa', 1: 'Aguas_lluvias', 2: 'Aguatero', 3: 'Carro_tanque', 4: 'De_acueducto_por_tubería', 5: 'De_otra_fuente_por_tubería', 6: 'De_pila_pública', 7: 'De_pozo_con_bomba', 8: 'De_pozo_sin_bomba_aljibe_jagüey_o_barreno', 9: 'Río_quebrada_nacimiento_o_manantial'}
# Lugar_donde_se_preparan_los_alimentos: {0: 'En_ninguna_parte_no_preparan_alimentos', 1: 'En_un_cuarto_usado_solo_para_cocinar', 2: 'En_un_cuarto_usado_también_para_dormir', 3: 'En_un_patio_corredor_enramada_al_aire_libre', 4: 'En_una_sala_comedor_con_lavaplatos', 5: 'En_una_sala_comedor_sin_lavaplatos'}
# Tipo_de_energía_o_combustible_usado_para_cocinar: {0: 'Carbón_mineral', 1: 'Electricidad', 2: 'Gas_natural_conectado_a_red_pública', 3: 'Gas_propano_en_cilindro_o_pipeta', 4: 'Leña_madera_o_carbón_de_leña', 5: 'Materiales_de_desecho', 6: 'Petróleo_gasolina_kerosene_alcohol'}
# Tipo_de_ocupación_de_la_vivienda: {0: 'En_arriendo_o_subarriendo', 1: 'En_usufructo', 2: 'Otra', 3: 'Posesión_sin_título', 4: 'Propia_la_están_pagando', 5: 'Propia_totalmente_pagada', 6: 'Propiedad_colectiva'}

# %%
# Convertir las variables categóricas a int64
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
df[categorical_cols] = df[categorical_cols].astype('int64')

# Verificar los cambios
print(df.dtypes)
# Out:
# key_ninos                                               int64
# primary_key                                             int64
# Departamento                                             int8
# Sexo_al_nacer                                            int8
# Edad_en_años_cumplidos                                  int64
#                                                        ...
# Lugar_donde_se_preparan_los_alimentos                    int8
# Tipo_de_energía_o_combustible_usado_para_cocinar         int8
# Tipo_de_ocupación_de_la_vivienda                         int8
# Valor_estimado_de_arriendo_si_se_tuviera_que_pagar    float64
# Total_de_personas_en_el_hogar                         float64
# Length: 63, dtype: object

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Select numerical columns for standardization
numerical_columns = df.select_dtypes(include=['int64', 'float64','int8']).columns

# Apply standardization
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
df
# Out:
#         key_ninos  primary_key  Departamento  Sexo_al_nacer  \
# 0       -0.103668    -1.719552     -0.248470       1.021449
# 1       -0.103667    -1.719511      1.096032       1.021449
# 2       -0.103667    -1.719471      1.096032       1.021449
# 3       -0.103666    -1.719461      1.096032      -0.979001
# 4       -0.103666    -1.719451      1.096032       1.021449
# ...           ...          ...           ...            ...
# 176343  -0.043001     0.878678      1.544199       1.021449
# 176344  -0.043001     0.878698     -0.920721      -0.979001
# 176345  -0.043001     0.878698     -0.920721       1.021449
# 176346  -0.043001     0.878708     -1.705014      -0.979001
# 176347  -0.043000     0.878748      1.544199      -0.979001
#
#         Edad_en_años_cumplidos  Parentesco_con_el_jefea_del_hogar  \
# 0                    -1.116687                          -0.499811
# 1                     0.492447                          -0.499811
# 2                     1.565202                          -0.499811
# 3                     0.492447                           2.150382
# 4                     1.565202                          -0.499811
# ...                        ...                                ...
# 176343               -1.653064                           2.150382
# 176344                1.297013                          -0.499811
# 176345               -0.580309                          -0.499811
# 176346               -0.312120                          -0.499811
# 176347               -0.580309                          -0.499811
#
#         ¿Madre_reside_en_el_hogar?  ¿Padre_reside_en_el_hogar?  \
# 0                         0.398933                   -0.795657
# 1                         0.398933                    1.006294
# 2                         0.398933                   -0.795657
# 3                         0.398933                   -0.795657
# 4                         0.398933                    1.006294
# ...                            ...                         ...
# 176343                    0.398933                    1.006294
# 176344                    0.398933                   -0.795657
# 176345                    0.398933                   -0.795657
# 176346                    0.398933                    1.006294
# 176347                    0.398933                    1.006294
#
#         ¿Se_considera_campesinoa?  ¿Alguna_vez_fue_campesinoa?  ...  \
# 0                        1.959271                    -0.078863  ...
# 1                        1.959271                    -0.078863  ...
# 2                        1.959271                    -0.078863  ...
# 3                       -0.510394                    -0.078863  ...
# 4                        1.959271                    -0.078863  ...
# ...                           ...                          ...  ...
# 176343                  -0.510394                    -0.078863  ...
# 176344                   1.959271                    -0.078863  ...
# 176345                   1.959271                    -0.078863  ...
# 176346                   1.959271                    -0.078863  ...
# 176347                  -0.510394                    -0.078863  ...
#
#         Número_de_cuartos_usados_para_dormir  \
# 0                                  -0.420021
# 1                                   0.819936
# 2                                  -1.659978
# 3                                  -0.420021
# 4                                  -1.659978
# ...                                      ...
# 176343                              0.819936
# 176344                              2.059893
# 176345                              2.059893
# 176346                              0.819936
# 176347                              0.819936
#
#         Tipo_de_servicio_sanitario_que_utiliza_el_hogar  \
# 0                                             -0.446996
# 1                                              0.761634
# 2                                              0.761634
# 3                                              0.761634
# 4                                              0.761634
# ...                                                 ...
# 176343                                        -0.446996
# 176344                                         1.970264
# 176345                                         1.970264
# 176346                                        -0.446996
# 176347                                        -0.446996
#
#         Forma_de_disposición_del_servicio_sanitario  \
# 0                                          0.142796
# 1                                          0.142796
# 2                                          0.142796
# 3                                          0.142796
# 4                                          0.142796
# ...                                             ...
# 176343                                     0.142796
# 176344                                     0.142796
# 176345                                     0.142796
# 176346                                     0.142796
# 176347                                     0.142796
#
#         Método_de_eliminación_de_basuras_en_el_hogar  \
# 0                                           0.345248
# 1                                           0.345248
# 2                                           0.345248
# 3                                           0.345248
# 4                                           0.345248
# ...                                              ...
# 176343                                      0.345248
# 176344                                      0.345248
# 176345                                      0.345248
# 176346                                      0.345248
# 176347                                      0.345248
#
#         Fuente_principal_de_agua_para_consumo_humano  \
# 0                                           0.006170
# 1                                           0.006170
# 2                                           0.006170
# 3                                           0.006170
# 4                                           0.006170
# ...                                              ...
# 176343                                      0.006170
# 176344                                      0.769199
# 176345                                      0.769199
# 176346                                      0.006170
# 176347                                      0.006170
#
#         Lugar_donde_se_preparan_los_alimentos  \
# 0                                   -0.451025
# 1                                   -0.451025
# 2                                   -0.451025
# 3                                    2.243999
# 4                                   -0.451025
# ...                                       ...
# 176343                              -0.451025
# 176344                              -0.451025
# 176345                              -0.451025
# 176346                              -0.451025
# 176347                              -0.451025
#
#         Tipo_de_energía_o_combustible_usado_para_cocinar  \
# 0                                               0.973052
# 1                                              -0.543347
# 2                                              -0.543347
# 3                                              -0.543347
# 4                                              -0.543347
# ...                                                  ...
# 176343                                         -0.543347
# 176344                                          0.973052
# 176345                                          0.973052
# 176346                                         -0.543347
# 176347                                         -0.543347
#
#         Tipo_de_ocupación_de_la_vivienda  \
# 0                              -0.816493
# 1                              -0.816493
# 2                              -0.355075
# 3                               1.490597
# 4                              -0.816493
# ...                                  ...
# 176343                          1.490597
# 176344                          1.490597
# 176345                          1.490597
# 176346                         -0.816493
# 176347                         -0.816493
#
#         Valor_estimado_de_arriendo_si_se_tuviera_que_pagar  \
# 0                                                0.000000
# 1                                                0.000000
# 2                                               -0.058530
# 3                                               -0.101703
# 4                                                0.000000
# ...                                                   ...
# 176343                                          -0.134062
# 176344                                          -0.026150
# 176345                                          -0.026150
# 176346                                           0.000000
# 176347                                           0.000000
#
#         Total_de_personas_en_el_hogar
# 0                           -0.907843
# 1                            0.281332
# 2                           -1.502431
# 3                            0.281332
# 4                            0.281332
# ...                               ...
# 176343                       0.281332
# 176344                       1.470508
# 176345                       1.470508
# 176346                      -0.907843
# 176347                      -0.313255
#
# [176348 rows x 63 columns]

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Compute the correlation matrix
correlation_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
df['trabajo_infantil'] = df_trabajo['trabajo_infantil']

# %%
df
# Out:
#         key_ninos  primary_key  Departamento  Sexo_al_nacer  \
# 0       -0.103668    -1.719552     -0.248470       1.021449
# 1       -0.103667    -1.719511      1.096032       1.021449
# 2       -0.103667    -1.719471      1.096032       1.021449
# 3       -0.103666    -1.719461      1.096032      -0.979001
# 4       -0.103666    -1.719451      1.096032       1.021449
# ...           ...          ...           ...            ...
# 176343  -0.043001     0.878678      1.544199       1.021449
# 176344  -0.043001     0.878698     -0.920721      -0.979001
# 176345  -0.043001     0.878698     -0.920721       1.021449
# 176346  -0.043001     0.878708     -1.705014      -0.979001
# 176347  -0.043000     0.878748      1.544199      -0.979001
#
#         Edad_en_años_cumplidos  Parentesco_con_el_jefea_del_hogar  \
# 0                    -1.116687                          -0.499811
# 1                     0.492447                          -0.499811
# 2                     1.565202                          -0.499811
# 3                     0.492447                           2.150382
# 4                     1.565202                          -0.499811
# ...                        ...                                ...
# 176343               -1.653064                           2.150382
# 176344                1.297013                          -0.499811
# 176345               -0.580309                          -0.499811
# 176346               -0.312120                          -0.499811
# 176347               -0.580309                          -0.499811
#
#         ¿Madre_reside_en_el_hogar?  ¿Padre_reside_en_el_hogar?  \
# 0                         0.398933                   -0.795657
# 1                         0.398933                    1.006294
# 2                         0.398933                   -0.795657
# 3                         0.398933                   -0.795657
# 4                         0.398933                    1.006294
# ...                            ...                         ...
# 176343                    0.398933                    1.006294
# 176344                    0.398933                   -0.795657
# 176345                    0.398933                   -0.795657
# 176346                    0.398933                    1.006294
# 176347                    0.398933                    1.006294
#
#         ¿Se_considera_campesinoa?  ¿Alguna_vez_fue_campesinoa?  ...  \
# 0                        1.959271                    -0.078863  ...
# 1                        1.959271                    -0.078863  ...
# 2                        1.959271                    -0.078863  ...
# 3                       -0.510394                    -0.078863  ...
# 4                        1.959271                    -0.078863  ...
# ...                           ...                          ...  ...
# 176343                  -0.510394                    -0.078863  ...
# 176344                   1.959271                    -0.078863  ...
# 176345                   1.959271                    -0.078863  ...
# 176346                   1.959271                    -0.078863  ...
# 176347                  -0.510394                    -0.078863  ...
#
#         Tipo_de_servicio_sanitario_que_utiliza_el_hogar  \
# 0                                             -0.446996
# 1                                              0.761634
# 2                                              0.761634
# 3                                              0.761634
# 4                                              0.761634
# ...                                                 ...
# 176343                                        -0.446996
# 176344                                         1.970264
# 176345                                         1.970264
# 176346                                        -0.446996
# 176347                                        -0.446996
#
#         Forma_de_disposición_del_servicio_sanitario  \
# 0                                          0.142796
# 1                                          0.142796
# 2                                          0.142796
# 3                                          0.142796
# 4                                          0.142796
# ...                                             ...
# 176343                                     0.142796
# 176344                                     0.142796
# 176345                                     0.142796
# 176346                                     0.142796
# 176347                                     0.142796
#
#         Método_de_eliminación_de_basuras_en_el_hogar  \
# 0                                           0.345248
# 1                                           0.345248
# 2                                           0.345248
# 3                                           0.345248
# 4                                           0.345248
# ...                                              ...
# 176343                                      0.345248
# 176344                                      0.345248
# 176345                                      0.345248
# 176346                                      0.345248
# 176347                                      0.345248
#
#         Fuente_principal_de_agua_para_consumo_humano  \
# 0                                           0.006170
# 1                                           0.006170
# 2                                           0.006170
# 3                                           0.006170
# 4                                           0.006170
# ...                                              ...
# 176343                                      0.006170
# 176344                                      0.769199
# 176345                                      0.769199
# 176346                                      0.006170
# 176347                                      0.006170
#
#         Lugar_donde_se_preparan_los_alimentos  \
# 0                                   -0.451025
# 1                                   -0.451025
# 2                                   -0.451025
# 3                                    2.243999
# 4                                   -0.451025
# ...                                       ...
# 176343                              -0.451025
# 176344                              -0.451025
# 176345                              -0.451025
# 176346                              -0.451025
# 176347                              -0.451025
#
#         Tipo_de_energía_o_combustible_usado_para_cocinar  \
# 0                                               0.973052
# 1                                              -0.543347
# 2                                              -0.543347
# 3                                              -0.543347
# 4                                              -0.543347
# ...                                                  ...
# 176343                                         -0.543347
# 176344                                          0.973052
# 176345                                          0.973052
# 176346                                         -0.543347
# 176347                                         -0.543347
#
#         Tipo_de_ocupación_de_la_vivienda  \
# 0                              -0.816493
# 1                              -0.816493
# 2                              -0.355075
# 3                               1.490597
# 4                              -0.816493
# ...                                  ...
# 176343                          1.490597
# 176344                          1.490597
# 176345                          1.490597
# 176346                         -0.816493
# 176347                         -0.816493
#
#         Valor_estimado_de_arriendo_si_se_tuviera_que_pagar  \
# 0                                                0.000000
# 1                                                0.000000
# 2                                               -0.058530
# 3                                               -0.101703
# 4                                                0.000000
# ...                                                   ...
# 176343                                          -0.134062
# 176344                                          -0.026150
# 176345                                          -0.026150
# 176346                                           0.000000
# 176347                                           0.000000
#
#         Total_de_personas_en_el_hogar  trabajo_infantil
# 0                           -0.907843              True
# 1                            0.281332              True
# 2                           -1.502431              True
# 3                            0.281332              True
# 4                            0.281332              True
# ...                               ...               ...
# 176343                       0.281332              True
# 176344                       1.470508              True
# 176345                       1.470508              True
# 176346                      -0.907843              True
# 176347                      -0.313255              True
#
# [176348 rows x 64 columns]

# %%
# Identificar pares de variables con alta correlación
threshold = 0.8  # Umbral de correlación
correlation_matrix = df.corr()

# Filtrar pares de variables con correlación mayor al umbral
high_correlation_pairs = correlation_matrix.stack().loc[lambda x: (x >= threshold) & (x < 1)]

# Mostrar las variables altamente correlacionadas
print(high_correlation_pairs)
# Out:
# ¿Se_considera_campesinoa?                        ¿Su_comunidad_es_campesina?                        0.862423
# ¿Su_comunidad_es_campesina?                      ¿Se_considera_campesinoa?                          0.862423
# Disponibilidad_de_recolección_de_basuras         Método_de_eliminación_de_basuras_en_el_hogar       0.962559
# Número_total_de_cuartos_disponibles_en_el_hogar  Número_de_cuartos_usados_para_dormir               0.802776
# Número_de_cuartos_usados_para_dormir             Número_total_de_cuartos_disponibles_en_el_hogar    0.802776
# Método_de_eliminación_de_basuras_en_el_hogar     Disponibilidad_de_recolección_de_basuras           0.962559
# dtype: float64

# %%
# Eliminar variables correlacionadas
correlated_variables = high_correlation_pairs.index.get_level_values(0).unique()
df = df.drop(columns=correlated_variables)

# Mostrar las columnas restantes
print(df.columns)
# Out:
# Index(['key_ninos', 'primary_key', 'Departamento', 'Sexo_al_nacer',
#        'Edad_en_años_cumplidos', 'Parentesco_con_el_jefea_del_hogar',
#        '¿Madre_reside_en_el_hogar?', '¿Padre_reside_en_el_hogar?',
#        '¿Alguna_vez_fue_campesinoa?', 'Autoidentificación_étnica',
#        'Estado_civil', '¿Cónyuge_reside_en_el_hogar?',
#        'COVID:_estuvo_enfermoa', 'COVID:_dificultad_con_alimentos/productos',
#        'COVID:_dificultad_con_pagos/deudas', 'COVID:_reducción_de_ingresos',
#        'COVID:_sin_trabajo_o_sin_poder_buscarlo',
#        'COVID:_suspensión_contrato_sin_paga',
#        'COVID:_pérdida_de_trabajo_o_ingresos', 'COVID:_suspensión_de_clases',
#        'COVID:_malestar_emocional', 'COVID:_otra_dificultad',
#        'COVID:_sin_dificultades', 'Afiliación_sistema_de_salud',
#        'Régimen_de_salud', 'Dificultad_auditiva', 'Dificultad_para_hablar',
#        'Dificultad_visual', 'Dificultad_motriz', 'Dificultad_en_manos',
#        'Dificultad_cognitiva', 'Dificultad_en_autocuidado',
#        'Dificultad_para_relacionarse', '¿Sabe_leer_y_escribir?',
#        '¿Asiste_actualmente_a_clase?', 'Tipo_de_institución_educativa',
#        'Nivel_educativo_y_grado_aprobado', 'Condición_de_discapacidad',
#        'Pertenencia_a_comunidad_campesina', 'Tipo_de_vivienda',
#        'Material_predominante_de_las_paredes_exteriores',
#        'Material_predominante_del_piso', 'Disponibilidad_de_energía_eléctrica',
#        'Estrato_para_tarifa_de_electricidad',
#        'Disponibilidad_de_gas_natural_por_red_pública',
#        'Disponibilidad_de_alcantarillado',
#        'Frecuencia_de_recolección_de_basura_(veces_por_semana)',
#        'Disponibilidad_de_acueducto', 'Cantidad_de_hogares_en_la_vivienda',
#        'Tipo_de_servicio_sanitario_que_utiliza_el_hogar',
#        'Forma_de_disposición_del_servicio_sanitario',
#        'Fuente_principal_de_agua_para_consumo_humano',
#        'Lugar_donde_se_preparan_los_alimentos',
#        'Tipo_de_energía_o_combustible_usado_para_cocinar',
#        'Tipo_de_ocupación_de_la_vivienda',
#        'Valor_estimado_de_arriendo_si_se_tuviera_que_pagar',
#        'Total_de_personas_en_el_hogar', 'trabajo_infantil'],
#       dtype='object')

# %%
df.to_csv(r'C:\Users\ASUS\Downloads\df.csv', index=False)
